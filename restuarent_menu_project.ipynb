# %% [markdown]
# # Restaurent Menu Project

# %%
menu = {
        'Pizza':60,
        'Burger':80,
        'coffee':60,
        'choemein':50,
        'Manchurian':50,
}

print(menu)







print('Welcome To Our Restaurent! , Here Is Our Menu')
print('')

print("Pizza: 60\nBurger: 80\nCoffee: 60\nchowmein:50\nManchurian: 50")


order_total=0




order=input("What would you like to have?   :")
if order in menu:
	order_total+=menu[order]
		
	
print(" Would you like to have anything else??")
choice=input("yes/no   :")
if(choice=="yes"):
		order=input("what else would you like to have ??     :")
		if order in menu:
			order_total+=menu[order]


print("Your total order value is",order_total)

            
        




print("Thank you for ordering")
# Out:
# {'Pizza': 60, 'Burger': 80, 'coffee': 60, 'choemein': 50, 'Manchurian': 50}
# Welcome To Our Restaurent! , Here Is Our Menu
#
# Pizza: 60
# Burger: 80
# Coffee: 60
# chowmein:50
# Manchurian: 50

# %%
menu
# Out:
# {'Pizza': 60, 'Burger': 80, 'coffee': 60, 'choemein': 50, 'Manchurian': 50}

# %%
print("Pizza: 60\nBurger: 80\nCoffee: 60\nchowmein:50\nManchurian: 50")
# Out:
# Pizza: 60
# Burger: 80
# Coffee: 60
# chowmein:50
# Manchurian: 50
